# %%
import pandas as pd

# %% [markdown]
# # Create new Record

# %%
# Specify the encoding
data = pd.read_csv("C:\\Users\\ASUS\\Downloads\\car_purchasing.csv", encoding="latin1")  # Try 'latin1'
data.head()
# Out:
#      customer name                                    customer e-mail  \
# 0    Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1    Harlan Barnes                                eu.dolor@diam.co.uk
# 2  Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3  Jade Cunningham                            malesuada@dignissim.com
# 4     Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
#
#         country  gender        age  annual Salary  credit card debt  \
# 0      Bulgaria       0  41.851720    62812.09301      11609.380910
# 1        Belize       0  40.870623    66646.89292       9572.957136
# 2       Algeria       1  43.152897    53798.55112      11160.355060
# 3  Cook Islands       1  58.271369    79370.03798      14426.164850
# 4        Brazil       1  57.313749    59729.15130       5358.712177
#
#      net worth  car purchase amount
# 0  238961.2505          35321.45877
# 1  530973.9078          45115.52566
# ...

# %%
data.sample(3)
# Out:
#           customer name                        customer e-mail  \
# 150        Nolan Conner                 feugiat@felisNulla.org
# 255      Damon K. Boone                             nec@ad.net
# 303  Chambers, Avram C.  Nunc.pulvinar.arcu@ultricesaauctor.ca
#
#                          country  gender        age  annual Salary  \
# 150                      Bolivia       1  45.497325    51906.85022
# 255  French Southern Territories       1  42.803865    54749.88645
# 303                  Isle of Man       1  62.868861    75719.22986
#
#      credit card debt     net worth  car purchase amount
# 150      13686.969350   85520.85055          27810.21814
# 255       7631.687821  152883.35190          29092.13110
# 303      10515.281350  474485.66590          67092.23276

# %%
# New record to add
new_record = {
    'customer name': 'srushti bagde',
    'customer e-mail': 'spbagde1@gmail.com', 
    'country': 'India', 
    'gende': 0,
    'age':22,
    'annual Salary':33421.04568,
    'credit card debt':125365.0986,
    'net worth': 34146.7858,
    'car purchase amount':25567.7868
    
}

# %%
# Convert the new record into a DataFrame
new_data = pd.DataFrame([new_record])

# %%
# Concatenate the new record with the existing dataset
data = pd.concat([data, new_data], ignore_index=True)

# Display the updated dataset
data
# Out:
#        customer name                                    customer e-mail  \
# 0      Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1      Harlan Barnes                                eu.dolor@diam.co.uk
# 2    Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3    Jade Cunningham                            malesuada@dignissim.com
# 4       Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
# ..               ...                                                ...
# 499            Marla                          Camaron.marla@hotmail.com
# 500      Alice Brown                            alice.brown@example.com
# 501      Alice Brown                            alice.brown@example.com
# 502    srushti bagde                                 spbagde1@gmail.com
# 503    srushti bagde                                 spbagde1@gmail.com
#
#           country  gender        age  annual Salary  credit card debt  \
# ...

# %% [markdown]
# # Read operation

# %%
data = pd.read_csv("C:\\Users\\ASUS\\Downloads\\car_purchasing.csv", encoding="latin1")  # Try 'latin1'
data.head()
# Out:
#      customer name                                    customer e-mail  \
# 0    Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1    Harlan Barnes                                eu.dolor@diam.co.uk
# 2  Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3  Jade Cunningham                            malesuada@dignissim.com
# 4     Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
#
#         country  gender        age  annual Salary  credit card debt  \
# 0      Bulgaria       0  41.851720    62812.09301      11609.380910
# 1        Belize       0  40.870623    66646.89292       9572.957136
# 2       Algeria       1  43.152897    53798.55112      11160.355060
# 3  Cook Islands       1  58.271369    79370.03798      14426.164850
# 4        Brazil       1  57.313749    59729.15130       5358.712177
#
#      net worth  car purchase amount
# 0  238961.2505          35321.45877
# 1  530973.9078          45115.52566
# ...

# %%
# READ: Retrieve specific records
[data['age'] >26]  # Filter rows where Age > 26
# Out:
# [0      True
#  1      True
#  2      True
#  3      True
#  4      True
#         ...
#  495    True
#  496    True
#  497    True
#  498    True
#  499    True
#  Name: age, Length: 500, dtype: bool]

# %%
data[data['age'] > 26]  # only that row where age >26
# Out:
#        customer name                                    customer e-mail  \
# 0      Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1      Harlan Barnes                                eu.dolor@diam.co.uk
# 2    Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3    Jade Cunningham                            malesuada@dignissim.com
# 4       Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
# ..               ...                                                ...
# 495           Walter                                ligula@Cumsociis.ca
# 496            Vanna                 Cum.sociis.natoque@Sedmolestie.edu
# 497            Pearl                      penatibus.et@massanonante.com
# 498             Nell                  Quisque.varius@arcuVivamussit.net
# 499            Marla                          Camaron.marla@hotmail.com
#
#           country  gender        age  annual Salary  credit card debt  \
# ...

# %% [markdown]
# # Update operation

# %%
# lets modify age
data = pd.read_csv("C:\\Users\\ASUS\\Downloads\\car_purchasing.csv", encoding="latin1")  # Try 'latin1'
data.head()
# Out:
#      customer name                                    customer e-mail  \
# 0    Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1    Harlan Barnes                                eu.dolor@diam.co.uk
# 2  Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3  Jade Cunningham                            malesuada@dignissim.com
# 4     Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
#
#         country  gender        age  annual Salary  credit card debt  \
# 0      Bulgaria       0  41.851720    62812.09301      11609.380910
# 1        Belize       0  40.870623    66646.89292       9572.957136
# 2       Algeria       1  43.152897    53798.55112      11160.355060
# 3  Cook Islands       1  58.271369    79370.03798      14426.164850
# 4        Brazil       1  57.313749    59729.15130       5358.712177
#
#      net worth  car purchase amount
# 0  238961.2505          35321.45877
# 1  530973.9078          45115.52566
# ...

# %%
data.loc[data['customer name'] == 'Martina Avila','age'] = 30

# %%
data.head(1)
# Out:
#    customer name                                    customer e-mail   country  \
# 0  Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu  Bulgaria
#
#    gender   age  annual Salary  credit card debt    net worth  \
# 0       0  30.0    62812.09301       11609.38091  238961.2505
#
#    car purchase amount
# 0          35321.45877

# %% [markdown]
# # Delete Operation

# %%
data = pd.read_csv("C:\\Users\\ASUS\\Downloads\\car_purchasing.csv", encoding="latin1")  # Try 'latin1'
data.head()
# Out:
#      customer name                                    customer e-mail  \
# 0    Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1    Harlan Barnes                                eu.dolor@diam.co.uk
# 2  Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3  Jade Cunningham                            malesuada@dignissim.com
# 4     Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
#
#         country  gender        age  annual Salary  credit card debt  \
# 0      Bulgaria       0  41.851720    62812.09301      11609.380910
# 1        Belize       0  40.870623    66646.89292       9572.957136
# 2       Algeria       1  43.152897    53798.55112      11160.355060
# 3  Cook Islands       1  58.271369    79370.03798      14426.164850
# 4        Brazil       1  57.313749    59729.15130       5358.712177
#
#      net worth  car purchase amount
# 0  238961.2505          35321.45877
# 1  530973.9078          45115.52566
# ...

# %%
data.drop(index = [1,2,6,7])    # it will remove row
# Out:
#        customer name                                    customer e-mail  \
# 0      Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 3    Jade Cunningham                            malesuada@dignissim.com
# 4       Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
# 5       Carla Hester                                 mi@Aliquamerat.edu
# 8       Marny Obrien                        Phasellus@sedsemegestas.org
# ..               ...                                                ...
# 495           Walter                                ligula@Cumsociis.ca
# 496            Vanna                 Cum.sociis.natoque@Sedmolestie.edu
# 497            Pearl                      penatibus.et@massanonante.com
# 498             Nell                  Quisque.varius@arcuVivamussit.net
# 499            Marla                          Camaron.marla@hotmail.com
#
#           country  gender        age  annual Salary  credit card debt  \
# ...

# %%
# you can also remove column
data.drop(columns = ['customer name','customer e-mail'])
# Out:
#           country  gender        age  annual Salary  credit card debt  \
# 0        Bulgaria       0  41.851720    62812.09301      11609.380910
# 1          Belize       0  40.870623    66646.89292       9572.957136
# 2         Algeria       1  43.152897    53798.55112      11160.355060
# 3    Cook Islands       1  58.271369    79370.03798      14426.164850
# 4          Brazil       1  57.313749    59729.15130       5358.712177
# ..            ...     ...        ...            ...               ...
# 495         Nepal       0  41.462515    71942.40291       6995.902524
# 496      Zimbabwe       1  37.642000    56039.49793      12301.456790
# 497   Philippines       1  53.943497    68888.77805      10611.606860
# 498      Botswana       1  59.160509    49811.99062      14013.034510
# 499        marlal       1  46.731152    61370.67766       9391.341628
#
#        net worth  car purchase amount
# 0    238961.2505          35321.45877
# 1    530973.9078          45115.52566
# ...
